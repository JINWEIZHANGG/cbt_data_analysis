# %% [markdown]
# # Run all notebooks in the project

# %%
# %run notebooks/ecg_00.ipynb
# Out:
# ecg_00.ipynb finished

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load ECG data from the correct path
data = np.loadtxt('data/ECG_hz.txt') # if use ('../data/ECG_hz.txt') depends on your current working directory


plt.plot(data)
plt.title("ECG Signal")
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.show()
